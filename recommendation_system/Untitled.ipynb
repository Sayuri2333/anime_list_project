# %%
import pandas as pd
# dealing with csv file
def deal_csv(input_file, output_file):
    data_origin = pd.read_csv(input_file, sep=',', encoding='ISO-8859-1', header=None, names=headers)
    data_origin[['username', 'anime_id', 'my_last_updated', 'my_score']].to_csv(output_file, sep=',', header=None, index=None)

# %%
data_origin = pd.read_csv("anime_cleaned.csv")
data_origin.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
data_origin['studio'].head()
# Out:
# 0    David Production
# 1               Gonzo
# 2           Satelight
# 3      Hal Film Maker
# 4           J.C.Staff
# Name: studio, dtype: object

# %%
data_origin[['anime_id', 'title', 'title_japanese', 'image_url', 'type', 'source', 'episodes', 'status', 'aired_string', 'duration', 'rating', 'score', 'scored_by', 'rank', 'popularity', 'studio', 'genre']].to_csv("selected_anime.csv", sep=',', index=None)

# %%
data_origin = pd.read_csv("selected_anime.csv")
data_origin.tail()
# Out:
#       anime_id                                              title  \
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                           title_japanese  \
# 6663                     dokidokiりとる大家さん
# 6664                           我是江小白 小剧场
# 6665                 げんきげんきノンタン　おばけむらめいろ
# 6666  Mr. Men Little Miss / ミスターメン リトルミス
# 6667             むしむし村の仲間たち　みんないいとこあるんだよ
#
#                                               image_url type        source  \
# 6663  https://myanimelist.cdn-dena.com/images/anime/...  OVA         Other
# 6664  https://myanimelist.cdn-dena.com/images/anime/...  ONA      Original
# 6665  https://myanimelist.cdn-dena.com/images/anime/...  OVA      Original
# ...
